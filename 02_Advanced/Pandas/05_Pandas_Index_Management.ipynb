# %% [markdown]
# # Index Management
#
# df.sort_index()

# %%
# Importing Libraries
import pandas as pd
from datasets import load_dataset
import matplotlib.pyplot as plt

# loading data
dataset = load_dataset("lukebarousse/data_jobs")
df = dataset['train'].to_pandas()

# Data cleaning
df['job_posted_date'] = pd.to_datetime(df['job_posted_date'])

# %%
df.sample(5)
# Out:
#          job_title_short                    job_title   job_location  \
# 380698     Data Engineer            GCP data Engineer       Anywhere
# 153994  Business Analyst            Hardware Engineer      Singapore
# 610411     Data Engineer  Sr. Manager - Data Engineer  Annapolis, MD
# 207564    Data Scientist         IT Data Scientist-KR       Anywhere
# 405682     Data Engineer                Data Engineer    Raleigh, NC
#
#                       job_via job_schedule_type  job_work_from_home  \
# 380698           via LinkedIn         Full-time                True
# 153994  via WS Audiology APAC         Full-time               False
# 610411            via Monster         Full-time               False
# 207564             via Indeed         Full-time                True
# 405682           via LinkedIn         Full-time               False
#
#                   search_location     job_posted_date  job_no_degree_mention  \
# 380698                      Sudan 2023-05-09 20:28:10                  False
# 153994                  Singapore 2023-01-05 08:42:31                   True
# 610411  California, United States 2023-03-01 12:15:46                  False
# 207564                     Mexico 2023-12-21 22:11:18                  False
# 405682                    Georgia 2023-12-20 16:32:24                  False
#
#         job_health_insurance    job_country salary_rate  salary_year_avg  \
# 380698                 False          Sudan        None              NaN
# 153994                 False      Singapore        None              NaN
# 610411                  True  United States        None              NaN
# 207564                 False         Mexico        None              NaN
# 405682                  True  United States        None              NaN
#
#         salary_hour_avg       company_name  \
# 380698              NaN          Cognizant
# 153994              NaN  WS Audiology APAC
# 610411              NaN        Capital One
# 207564              NaN             Praxis
# 405682              NaN               Zifo
#
#                                                job_skills  \
# 380698  ['sql', 'gcp', 'bigquery', 'oracle', 'airflow'...
# 153994                                               None
# 610411  ['java', 'scala', 'python', 'nosql', 'sql', 'm...
# 207564  ['python', 'r', 'aws', 'azure', 'gcp', 'power ...
# 405682  ['python', 'java', 'scala', 'sql', 'nosql', 'm...
#
#                                           job_type_skills
# 380698  {'cloud': ['gcp', 'bigquery', 'oracle'], 'libr...
# 153994                                               None
# 610411  {'cloud': ['redshift', 'snowflake', 'aws', 'az...
# 207564  {'analyst_tools': ['power bi', 'tableau'], 'cl...
# 405682  {'analyst_tools': ['tableau', 'power bi'], 'cl...

# %%
df.index
# Out:
# RangeIndex(start=0, stop=785741, step=1)

# %%
df.index.name = 'job_index'

# %%
df.head()
# Out:
#                 job_title_short  \
# job_index
# 0          Senior Data Engineer
# 1                  Data Analyst
# 2                 Data Engineer
# 3                 Data Engineer
# 4                 Data Engineer
#
#                                                    job_title  \
# job_index
# 0          Senior Clinical Data Engineer / Principal Clin...
# 1                                               Data Analyst
# 2          Data Engineer/Scientist/Analyst, Mid or Senior...
# 3          LEAD ENGINEER - PRINCIPAL ANALYST - PRINCIPAL ...
# 4                                     Data Engineer- Sr Jobs
#
#                            job_location             job_via job_schedule_type  \
# job_index
# 0                         Watertown, CT     via Work Nearby         Full-time
# 1          Guadalajara, Jalisco, Mexico    via BeBee México         Full-time
# 2                       Berlin, Germany        via LinkedIn         Full-time
# 3                       San Antonio, TX   via Diversity.com         Full-time
# 4                        Washington, DC  via Clearance Jobs         Full-time
#
#            job_work_from_home       search_location     job_posted_date  \
# job_index
# 0                       False  Texas, United States 2023-06-16 13:44:15
# 1                       False                Mexico 2023-01-14 13:18:07
# 2                       False               Germany 2023-10-10 13:14:55
# 3                       False  Texas, United States 2023-07-04 13:01:41
# 4                       False                 Sudan 2023-08-07 14:29:36
#
#            job_no_degree_mention  job_health_insurance    job_country  \
# job_index
# 0                          False                 False  United States
# 1                          False                 False         Mexico
# 2                          False                 False        Germany
# 3                           True                 False  United States
# 4                          False                 False          Sudan
#
#           salary_rate  salary_year_avg  salary_hour_avg  \
# job_index
# 0                None              NaN              NaN
# 1                None              NaN              NaN
# 2                None              NaN              NaN
# 3                None              NaN              NaN
# 4                None              NaN              NaN
#
#                            company_name  \
# job_index
# 0                  Boehringer Ingelheim
# 1            Hewlett Packard Enterprise
# 2              ALPHA Augmented Services
# 3          Southwest Research Institute
# 4                       Kristina Daniel
#
#                                                   job_skills  \
# job_index
# 0                                                       None
# 1          ['r', 'python', 'sql', 'nosql', 'power bi', 't...
# 2          ['python', 'sql', 'c#', 'azure', 'airflow', 'd...
# 3          ['python', 'c++', 'java', 'matlab', 'aws', 'te...
# 4          ['bash', 'python', 'oracle', 'aws', 'ansible',...
#
#                                              job_type_skills
# job_index
# 0                                                       None
# 1          {'analyst_tools': ['power bi', 'tableau'], 'pr...
# 2          {'analyst_tools': ['dax'], 'cloud': ['azure'],...
# 3          {'cloud': ['aws'], 'libraries': ['tensorflow',...
# 4          {'cloud': ['oracle', 'aws'], 'other': ['ansibl...

# %%
df.index.dtype
# Out:
# dtype('int64')

# %% [markdown]
# # Three Methods to cover
#
# * df.reset_index()
# * df.set_index()
# * df.sort_index()

# %% [markdown]
# # reset_index()

# %%
df_usa = df[df['job_country'] == 'United States']

df_usa.reset_index(inplace=True)

df_usa.head(10)
# Out:
#    job_index       job_title_short  \
# 0          0  Senior Data Engineer
# 1          3         Data Engineer
# 2          5         Data Engineer
# 3          6  Senior Data Engineer
# 4          9        Data Scientist
# 5         11         Data Engineer
# 6         13  Senior Data Engineer
# 7         17        Data Scientist
# 8         26         Data Engineer
# 9         27         Data Engineer
#
#                                            job_title  \
# 0  Senior Clinical Data Engineer / Principal Clin...
# 1  LEAD ENGINEER - PRINCIPAL ANALYST - PRINCIPAL ...
# 2                                  GCP Data Engineer
# 3                  Senior Data Engineer  - GCP Cloud
# 4                                  Data Scientist II
# 5                                      Data Engineer
# 6                               Senior Data Engineer
# 7                             Data Science Team Lead
# 8                                      Data Engineer
# 9  Principal Data Engineer (Lead), Knowledge Grap...
#
#                          job_location  \
# 0                       Watertown, CT
# 1                     San Antonio, TX
# 2                            Anywhere
# 3                        Dearborn, MI
# 4                            Anywhere
# 5  Colorado Springs, CO   (+3 others)
# 6                        New York, NY
# 7                          Laurel, MD
# 8                       United States
# 9                   San Francisco, CA
#
#                                              job_via  \
# 0                                    via Work Nearby
# 1                                  via Diversity.com
# 2                                   via ZipRecruiter
# 3                                       via LinkedIn
# 4                                   via ZipRecruiter
# 5                                       via The Muse
# 6                                       via LinkedIn
# 7  via APL Careers - Johns Hopkins University App...
# 8                                       via LinkedIn
# 9                                       via LinkedIn
#
#           job_schedule_type  job_work_from_home          search_location  \
# 0                 Full-time               False     Texas, United States
# 1                 Full-time               False     Texas, United States
# 2  Contractor and Temp work                True                  Georgia
# 3                 Full-time               False   Florida, United States
# 4                 Full-time                True  New York, United States
# 5                 Full-time               False     Texas, United States
# 6                 Full-time               False     Texas, United States
# 7                 Full-time               False                  Georgia
# 8                 Full-time               False                  Georgia
# 9                 Full-time               False                  Georgia
#
#       job_posted_date  job_no_degree_mention  job_health_insurance  \
# 0 2023-06-16 13:44:15                  False                 False
# 1 2023-07-04 13:01:41                   True                 False
# 2 2023-11-07 14:01:59                  False                 False
# 3 2023-03-27 13:18:18                  False                 False
# 4 2023-04-23 13:02:57                  False                 False
# 5 2023-11-03 13:06:51                  False                  True
# 6 2023-11-15 13:08:52                   True                  True
# 7 2023-06-13 13:25:17                  False                  True
# 8 2023-09-15 13:56:18                   True                 False
# 9 2023-02-18 13:31:24                  False                 False
#
#      job_country salary_rate  salary_year_avg  salary_hour_avg  \
# 0  United States        None              NaN              NaN
# 1  United States        None              NaN              NaN
# 2  United States        None              NaN              NaN
# 3  United States        None              NaN              NaN
# 4  United States        None              NaN              NaN
# 5  United States        None              NaN              NaN
# 6  United States        None              NaN              NaN
# 7  United States        None              NaN              NaN
# 8  United States        None              NaN              NaN
# 9  United States        None              NaN              NaN
#
#                                company_name  \
# 0                      Boehringer Ingelheim
# 1              Southwest Research Institute
# 2                           smart folks inc
# 3             Miracle Software Systems, Inc
# 4                Radwell International, LLC
# 5                                   Philips
# 6                                     Nayya
# 7  Johns Hopkins Applied Physics Laboratory
# 8               Infinite Computer Solutions
# 9                                Altos Labs
#
#                                           job_skills  \
# 0                                               None
# 1  ['python', 'c++', 'java', 'matlab', 'aws', 'te...
# 2                           ['python', 'sql', 'gcp']
# 3  ['sql', 'python', 'java', 'sql server', 'gcp',...
# 4  ['sql', 'python', 'r', 'mongodb', 'mongodb', '...
# 5                                 ['python', 'qlik']
# 6  ['python', 'sql', 'go', 'ruby', 'ruby', 'javas...
# 7                             ['go', 'apl', 'excel']
# 8                                               None
# 9                            ['python', 'r', 'java']
#
#                                      job_type_skills
# 0                                               None
# 1  {'cloud': ['aws'], 'libraries': ['tensorflow',...
# 2  {'cloud': ['gcp'], 'programming': ['python', '...
# 3  {'cloud': ['gcp', 'bigquery'], 'databases': ['...
# 4  {'analyst_tools': ['excel'], 'cloud': ['azure'...
# 5  {'analyst_tools': ['qlik'], 'programming': ['p...
# 6  {'cloud': ['aws'], 'other': ['terraform'], 'pr...
# 7  {'analyst_tools': ['excel'], 'programming': ['...
# 8                                               None
# 9           {'programming': ['python', 'r', 'java']}

# %% [markdown]
# # set_index()

# %%
df_usa.set_index('job_index', inplace=True)

df_usa
# Out:
#                 job_title_short  \
# job_index
# 0          Senior Data Engineer
# 3                 Data Engineer
# 5                 Data Engineer
# 6          Senior Data Engineer
# 9                Data Scientist
# ...                         ...
# 785673           Data Scientist
# 785685             Data Analyst
# 785692           Data Scientist
# 785703             Data Analyst
# 785705             Data Analyst
#
#                                                    job_title  \
# job_index
# 0          Senior Clinical Data Engineer / Principal Clin...
# 3          LEAD ENGINEER - PRINCIPAL ANALYST - PRINCIPAL ...
# 5                                          GCP Data Engineer
# 6                          Senior Data Engineer  - GCP Cloud
# 9                                          Data Scientist II
# ...                                                      ...
# 785673                       Asset Management Data Scientist
# 785685                                          Data Analyst
# 785692                  Data Scientist- Hybrid Work Location
# 785703               Data Analyst - CRYPTOGRAPHY - Full-time
# 785705             Expert Business Data Analyst - Now Hiring
#
#                job_location            job_via         job_schedule_type  \
# job_index
# 0             Watertown, CT    via Work Nearby                 Full-time
# 3           San Antonio, TX  via Diversity.com                 Full-time
# 5                  Anywhere   via ZipRecruiter  Contractor and Temp work
# 6              Dearborn, MI       via LinkedIn                 Full-time
# 9                  Anywhere   via ZipRecruiter                 Full-time
# ...                     ...                ...                       ...
# 785673         New York, NY    via Trabajo.org                 Full-time
# 785685     Indianapolis, IN    via Trabajo.org                 Full-time
# 785692           Dayton, OH    via Ai-Jobs.net                 Full-time
# 785703             Anywhere       via Snagajob                 Full-time
# 785705          Oakland, CA       via Snagajob                 Full-time
#
#            job_work_from_home            search_location     job_posted_date  \
# job_index
# 0                       False       Texas, United States 2023-06-16 13:44:15
# 3                       False       Texas, United States 2023-07-04 13:01:41
# 5                        True                    Georgia 2023-11-07 14:01:59
# 6                       False     Florida, United States 2023-03-27 13:18:18
# 9                        True    New York, United States 2023-04-23 13:02:57
# ...                       ...                        ...                 ...
# 785673                  False    New York, United States 2023-10-16 06:01:53
# 785685                  False    Illinois, United States 2023-07-16 06:01:27
# 785692                  False    Illinois, United States 2023-04-21 06:02:31
# 785703                   True       Texas, United States 2023-01-28 06:02:55
# 785705                  False  California, United States 2023-01-09 06:00:25
#
#            job_no_degree_mention  job_health_insurance    job_country  \
# job_index
# 0                          False                 False  United States
# 3                           True                 False  United States
# 5                          False                 False  United States
# 6                          False                 False  United States
# 9                          False                 False  United States
# ...                          ...                   ...            ...
# 785673                      True                 False  United States
# 785685                      True                 False  United States
# 785692                     False                  True  United States
# 785703                      True                 False  United States
# 785705                     False                 False  United States
#
#           salary_rate  salary_year_avg  salary_hour_avg  \
# job_index
# 0                None              NaN              NaN
# 3                None              NaN              NaN
# 5                None              NaN              NaN
# 6                None              NaN              NaN
# 9                None              NaN              NaN
# ...               ...              ...              ...
# 785673           None              NaN              NaN
# 785685           None              NaN              NaN
# 785692           year         157500.0              NaN
# 785703           None              NaN              NaN
# 785705           None              NaN              NaN
#
#                             company_name  \
# job_index
# 0                   Boehringer Ingelheim
# 3           Southwest Research Institute
# 5                        smart folks inc
# 6          Miracle Software Systems, Inc
# 9             Radwell International, LLC
# ...                                  ...
# 785673              JPMorgan Chase & Co.
# 785685            Aara Technologies, Inc
# 785692                            Tenet3
# 785703       Axelon Services Corporation
# 785705                  PG&E Corporation
#
#                                                   job_skills  \
# job_index
# 0                                                       None
# 3          ['python', 'c++', 'java', 'matlab', 'aws', 'te...
# 5                                   ['python', 'sql', 'gcp']
# 6          ['sql', 'python', 'java', 'sql server', 'gcp',...
# 9          ['sql', 'python', 'r', 'mongodb', 'mongodb', '...
# ...                                                      ...
# 785673                                                  None
# 785685                                      ['sql', 'excel']
# 785692                             ['python', 'matlab', 'r']
# 785703                                                  None
# 785705                          ['sql', 'python', 'tableau']
#
#                                              job_type_skills
# job_index
# 0                                                       None
# 3          {'cloud': ['aws'], 'libraries': ['tensorflow',...
# 5          {'cloud': ['gcp'], 'programming': ['python', '...
# 6          {'cloud': ['gcp', 'bigquery'], 'databases': ['...
# 9          {'analyst_tools': ['excel'], 'cloud': ['azure'...
# ...                                                      ...
# 785673                                                  None
# 785685     {'analyst_tools': ['excel'], 'programming': ['...
# 785692            {'programming': ['python', 'matlab', 'r']}
# 785703                                                  None
# 785705     {'analyst_tools': ['tableau'], 'programming': ...
#
# [206292 rows x 17 columns]
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %% [markdown]
# # sorted_index
